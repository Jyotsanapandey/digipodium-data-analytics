# %%
print("brahmastra",2022)
# Out:
# brahmastra 2022

# %%
print("hello")
# Out:
# hello

# %%
print("raju")
# Out:
# raju

# %%
print(1,2,3)
# Out:
# 1 2 3

# %%
a=10
print(a)
# Out:
# 10

# %%
city='lucknow'
state='uttar pradesh'
name='adam'
name='randolf'
n1,n2= 'ajay','vijay'

# %%
food =input()
print(food)
# Out:
# poha

# %%
name=input('enter your name')
print('welcome',name)
amount=input("how much tea you will you take?")
print=("why do you want ,'amount'tea?")
# Out:
# welcome jyotsana

# %%
a=10
a='apple'
type(a)

# %%
a="300"
print(a,type(a))
b=int (a)
a =int(a)
print(b,type(b))
print(a,type(a))

# %%
a=input("enter A=")
b=input("enter B=")
print(type(a),type(b))
a=int(a)
b=int(b)
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\DELL\OneDrive\Documents\data analytics\economics.ipynb Cell 11 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive/Documents/data%20analytics/economics.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> a=input("enter A=")
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive/Documents/data%20analytics/economics.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> b=input("enter B=")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive/Documents/data%20analytics/economics.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> print(type(a),type(b))
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive/Documents/data%20analytics/economics.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> a=int(a)
# ...

# %% [markdown]
# # operaters

# %%
x=10
y=20

# %%
x-y
# Out:
# -10

# %%
x*y
# Out:
# 200

# %%
x+y
# Out:
# 30

# %%
x/y
# Out:
# 0.5

# %%
x//y
# Out:
# 0

# %%
x**y
# Out:
# 100000000000000000000

# %%
x%y
# Out:
# 10

# %%
x=10

# %%
x+=5

# %%
x-=10

# %%
x*=3

# %%
z+=5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\DELL\OneDrive\Documents\data analytics\economics.ipynb Cell 26 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive/Documents/data%20analytics/economics.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> z+=5
#
# NameError: name 'z' is not defined

# %%
x>10
# Out:
# True

# %%
y<3
# Out:
# False

# %%
'apple'=='Apple'
# Out:
# False

# %%
x>5 and x>100
# Out:
# False

# %%
x>5 or x>1
# Out:
# True

# %%
not x>100
# Out:
# True

# %%
x is y
# Out:
# False

# %%
x is not y
# Out:
# True

# %%
a=[1,3,8,10,2]

# %%
2 in a
# Out:
# [True]

# %%
15 in a
# Out:
# False

# %% [markdown]
# ### formatted
# ### string and msg

# %%
l =10.5
b =6.10
area =l*b

# %%
print(l,b,area)
# Out:
# 10.5 6.1 64.05

# %%
print ("{}*{}".format(l,b,area))
# Out:
# 10.5*6.1

# %%
print(f'{l}*{b}={area}')
# Out:
# 10.5*6.1=64.05

# %%
print('{l}*{b}={area}')
# Out:
# {l}*{b}={area}

# %%
print('l*b=area')
# Out:
# l*b=area

# %%
print(f'{l}*{b}={area:.1f}')
# Out:
# 10.5*6.1=64.0

# %%
print(f'{l}*{b}={area:.2f}')
# Out:
# 10.5*6.1=64.05

# %% [markdown]
# # condition
# 1. if
# 2. if else
# 3. if elif else
# 4. nested if
# 5. match case

# %% [markdown]
# ### syntax
# ~~~
# if condition:
# ~~~
#     statement

# %%
if 100 > 10:
      print('100 is greater than 10')
# Out:
# 100 is greater than 10

# %%
if 5 > 10:
  print('5 is greater than 10')

# %%
a = 10
b = 20
if a < b:
    print('this is greater')
    print(f'{a} is greater than {b}')
# Out:
# this is greater
# 10 is greater than 20

# %%
data = input("enter the data: ")
if data.isalpha():
     print("this is string")
if data.isnumeric():
     print("this is a number")     
if data.isspace():
    print("thos is a space")
# Out:
# this is string

# %%
temp = 32
if temp > 25:
      print("it's hot ")
else:
      print("it's cold")
# Out:
# it's hot

# %%
fruit = input("what fruit do you like? ")
if fruit == 'apple':
    print('an apple keeps the doctor away')
elif fruit == 'mango':
    print('mango is the king of fruits')
elif fruit == 'banana':
    print('banana is a good source of potassium')
elif fruit == 'orange':
    print('orange is agood source of vitamin C')
else:
    print('not found in the database')
# Out:
# banana is a good source of potassium

# %%
username = input("enter your username:")
password = input("enter your password:")
if username == 'sam':
    if password == '123':
       print("welcome sam")
    else:
        print("wrong password")
else:
    print("wrong username")
# Out:
# welcome sam

# %%
if username == 'sam' and password == '123':
    print("welcome sam")
# Out:
# welcome sam

# %%
# this can also be written as
if username == 'sam' and password == '123':
    print ("welcome sam")
else:
    print ("wrong username or password")
# Out:
# welcome sam
