# %%
x = [1,2,3,4]

# %%
emp = ['amar','deep','finance',100,200,300,30,True,False,'Acme']

# %%
emp_dict = {
    'fname':'amar',
    'lname': 'deep',
    'dept' : 'finance',
    'salary' : 100,
    'bonus' : 200,
    'age': 31,
    'is_manager': True,
    'is_executive' : False,
    'company': 'Acme'}

# %%
print(emp_dict)
# Out:
# {'fname': 'amar', 'lname': 'deep', 'dept': 'finance', 'salary': 100, 'bonus': 200, 'age': 31, 'is_manager': True, 'is_executive': False, 'company': 'Acme'}

# %%
weather_data = {
    'data': '2019-01-01',
    'temp' : 32,
    'details':{
        'humidity':80,
        'wind':10,
        'pressure': 30,
        'aqi': 120
    },
    'city': 'lucknow',
    'type': 'sunshine',
    'icon' : '🥵'
}

# %%
list (weather_data.keys())  # keys function (date, temp ,etc)is use to get the keys from the data
# Out:
# ['data', 'temp', 'details', 'city', 'type', 'icon']

# %%
list(weather_data.values())
# Out:
# ['2019-01-01',
#  32,
#  {'humidity': 80, 'wind': 10, 'pressure': 30, 'aqi': 120},
#  'lucknow',
#  'sunshine',
#  '🥵']

# %%
list(emp_dict.key())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\DELL\OneDrive\Documents\data analytics\dictionary.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive/Documents/data%20analytics/dictionary.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> list(emp_dict.key())
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
weather_data['details']
# Out:
# {'humidity': 80, 'wind': 10, 'pressure': 30, 'aqi': 120}

# %%
weather_data['location']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\DELL\OneDrive\Documents\data analytics\dictionary.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive/Documents/data%20analytics/dictionary.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> weather_data['location']
#
# KeyError: 'location'

# %%
weather_data.get('temp')   # get function is used to get the data if you have it otherwise there will be no outout
# Out:
# 32

# %%
weather_data.get('location')

# %%
weather_data.get('city','not found')
# Out:
# 'lucknow'

# %%
weather_data.get('location','not found')
# Out:
# 'not found'

# %% [markdown]
# ### looping over a dictionary

# %%
for key in emp_dict:
    print(key,'=>',emp_dict[key])
# Out:
# fname => amar
# lname => deep
# dept => finance
# salary => 100
# bonus => 200
# age => 31
# is_manager => True
# is_executive => False
# company => Acme

# %%
# second pythonic way

# looping over a dictionary using items()
for key,value in emp_dict.items():       # when we use items functions then we get both value and keys from the data in the output and by default it only shows keys
    print(key,'=>',value)
# Out:
# fname => amar
# lname => deep
# dept => finance
# salary => 100
# bonus => 200
# age => 31
# is_manager => True
# is_executive => False
# company => Acme

# %%
emp_dict.items()
# Out:
# dict_items([('fname', 'amar'), ('lname', 'deep'), ('dept', 'finance'), ('salary', 100), ('bonus', 200), ('age', 31), ('is_manager', True), ('is_executive', False), ('company', 'Acme')])

# %%
# updating an entry in dictionary
weather_data['temp']= 35

# %%
weather_data
# Out:
# {'data': '2019-01-01',
#  'temp': 35,
#  'details': {'humidity': 80, 'wind': 10, 'pressure': 30, 'aqi': 120},
#  'city': 'lucknow',
#  'type': 'sunshine',
#  'icon': '🥵'}

# %% [markdown]
# ### adding data

# %%
# adding data 
emp_dict['designation'] = 'Asst A '
print(emp_dict)
# Out:
# {'fname': 'amar', 'lname': 'deep', 'dept': 'finance', 'salary': 100, 'bonus': 200, 'age': 31, 'is_manager': True, 'is_executive': False, 'company': 'Acme', 'designation': 'Asst A '}

# %% [markdown]
# ### updating data

# %%
# updating data 
emp_dict['designation'] = 'section manager '
# print(emp_dict)
emp_dict['salary'] = 30000
print(emp_dict)
# Out:
# {'fname': 'amar', 'lname': 'deep', 'dept': 'finance', 'salary': 30000, 'bonus': 200, 'age': 31, 'is_manager': True, 'is_executive': False, 'company': 'Acme', 'designation': 'section manager '}

# %% [markdown]
# ### removing data

# %%
if 'is_executive' in emp_dict:
     emp_dict.pop('is_executive')  # remove the an entry

# %%
emp_dict
# Out:
# {'fname': 'amar',
#  'lname': 'deep',
#  'dept': 'finance',
#  'salary': 30000,
#  'bonus': 200,
#  'age': 31,
#  'is_manager': True,
#  'company': 'Acme',
#  'designation': 'section manager '}

# %% [markdown]
# ### rule to pop function if the key is present in the data then only pop will give us the result otherwise it will crash

# %%
reports = {
    '001': {
        'name': 'amar',
        'subject':{'english':80,'maths':90,'science':95}
    },
     '002': {
        'name': 'vijay',
        'subject':{'english':70,'maths':60,'science':85}
    },
     '003': {
        'name': 'raj',
        'subject':{'english':60,'maths':50,'science':45}
    }
}

# %%
reports
# Out:
# {'001': {'name': 'amar',
#   'subject': {'english': 80, 'maths': 90, 'science': 95}},
#  '002': {'name': 'vijay',
#   'subject': {'english': 70, 'maths': 60, 'science': 85}},
#  '003': {'name': 'raj',
#   'subject': {'english': 60, 'maths': 50, 'science': 45}}}

# %%
for roll ,data in reports.items():
    print("roll no.",roll)
    for key , val in data.items():
        if isinstance(val,dict):  
            print(key)                  # isinstance  function is used to check the datatype of the element
            for sub,marks in val.items():
                print(sub,marks)
        else:
            print(key,val)
    print('--'*10)
# Out:
# roll no. 001
# name amar
# subject
# english 80
# maths 90
# science 95
# --------------------
# roll no. 002
# name vijay
# subject
# english 70
# maths 60
# science 85
# --------------------
# roll no. 003
# name raj
# subject
# english 60
# maths 50
# science 45
# --------------------

# %%
for roll ,data in reports.items():
    print("roll no.",roll)
    for key , val in data.items():
        if isinstance(val,dict):  
            print(key)    
            total = 0      # before loop set marks to 0        # isinstance  function is used to check the datatype of the element
            for sub,marks in val.items():
                print(sub,marks)
                total += marks
            print(f'total:{total}/300')
        else:
            print(key,val)
            
    print('--'*10)
# Out:
# roll no. 001
# name amar
# subject
# english 80
# maths 90
# science 95
# total:265/300
# --------------------
# roll no. 002
# name vijay
# subject
# english 70
# maths 60
# science 85
# total:215/300
# --------------------
# roll no. 003
# name raj
# subject
# english 60
# maths 50
# science 45
# total:155/300
# --------------------

# %%
for roll ,data in reports.items():
    print("roll no.",roll)
    for key , val in data.items():
        if isinstance(val,dict):  
            print(key)    
            total = 0      # before loop set marks to 0        # isinstance  function is used to check the datatype of the element
            for sub,marks in val.items():
                print(sub,marks)
                total += marks
            print(f'total:{total}/300')
            print(f'percentage:{total/300*100:.2f} %') 
        else:
            print(key,val)
            
    print('--'*10)
# Out:
# roll no. 001
# name amar
# subject
# english 80
# maths 90
# science 95
# total:265/300
# percentage:88.33 %
# --------------------
# roll no. 002
# name vijay
# subject
# english 70
# maths 60
# science 85
# total:215/300
# percentage:71.67 %
# --------------------
# roll no. 003
# name raj
# subject
# english 60
# maths 50
# science 45
# total:155/300
# percentage:51.67 %
# --------------------

# %% [markdown]
# ### File handling
# - open a file
# - reading a file (file which we can open in notepad we cannot open pdf , ppt from it)
# - writing a file
# - appending a file

# %%
f = open('hello.py')
print(f.read())
# Out:
# print('hello there')

# %%
f = open(r'C:\Users\DELL\OneDrive\Desktop\jyotsana.txt')   # r is raw format which is used to
content = f.read()
print(f'{len (content) } characters')
# Out:
# 0 characters

# %%
data = 'hi everyone,this is sample file'
with open('mydata.txt','w')as file :              # with is a keyword in python which run the task and close the task and saves it after that
    file.write(data)

# %%
# not to be used
# file = open('mydata.txt','w')
# file.write(data)
# file.close()

# %%
data = '\nthis is the new data that is going to be written'
with open('mydata.txt','a') as file:
    file.write(data)

# %%
file = 'bio.txt'
content = ''

while True:
    line = input('enter a line(or q to be quit):')
    if line == 'q':
        break
    content += line + '\n'

with open(file,'w') as f :
    f.write(content)
    print(f'File{file} saved')
# Out:
# Filebio.txt saved
