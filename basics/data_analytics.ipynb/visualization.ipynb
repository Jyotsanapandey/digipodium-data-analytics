# %% [markdown]
# #### VISUALIZATION
# - figure
# - axes
# -  plot
# - pie
# - bar
# - scattered
# - hist
# - box
# - step
# - subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y = [21,343,56,89,90,33,58,94]
plt.plot(y)
plt.show()

# %%
plt.figure(figsize = (3,4))
plt.pie(y)
plt.show()      # show() function will hide the unnecessary story

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2 , figsize = (15,2))
plt.show()

# %%
t = np.arange(-3 * np.pi, 3 * np.pi , 0.2)
x = np.sin(t)
y = np.cos(t)
fig, ax = plt.subplots(nrows = 1 , ncols = 2 , figsize = (15,2))
ax[0].plot(t,x,'r')
ax[1].bar(t,y)
plt.show()

# %%
t = np.arange(-3 * np.pi, 3 * np.pi , 0.2)
x = np.sin(t)
y = np.cos(t)
fig, ax = plt.subplots(nrows = 1, ncols = 2 , figsize = (15,2))
ax[0].plot(t,x,'r')
ax[1].scatter(t,y)
plt.show()

# %%
x = [100,200,300,400,500,600]
y = [10, 53 ,38, 22, 50,60]
plt.plot(x,y, linewidth = 2, color = 'orange' , marker = 's' ,markersize = 10 , markerfacecolor = 'red', markeredgecolor = 'black' ,linestyle = '-.' )
plt.show()

# %%
plt.plot?
# Out:
# Signature: plt.plot(*args, scalex=True, scaley=True, data=None, **kwargs)
# Docstring:
# Plot y versus x as lines and/or markers.
#
# Call signatures::
#
#     plot([x], y, [fmt], *, data=None, **kwargs)
#     plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
# The coordinates of the points or line nodes are given by *x*, *y*.
#
# The optional parameter *fmt* is a convenient way for defining basic
# formatting like color, marker and linestyle. It's a shortcut string
# notation described in the *Notes* section below.
#
# >>> plot(x, y)        # plot x and y using default line style and color
# >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
# >>> plot(y)           # plot y using x as index array 0..N-1
# >>> plot(y, 'r+')     # ditto, but with red plusses
#
# You can use `.Line2D` properties as keyword arguments for more
# control on the appearance. Line properties and *fmt* can be mixed.
# The following two calls yield identical results:
#
# ...

# %%
plt.plot(x,y, 'go--', linewidth = 2,  markersize = 10 , markerfacecolor = 'red', markeredgecolor = 'black' , )
plt.title ('Some graph showing something', fontdict = {'fontsize' : 15 , 'fontweight' : 'bold' , 'color' : 'green'})
plt.xlabel("X axis ki value")
plt.ylabel("Y axis ki value" , fontdict = {'color': 'red'})
plt.text(300,50, "This is a serious text here")
plt.annotate("Peak value", xy = (200,55), xytext = (200,30), arrowprops = dict (facecolor = 'black', shrink = 0.05))
plt.show()
